# %% [markdown]
# Andi Oxy Raihan M.R. | 231061006 | Sains Data (SD23) | UAS PROLAN

# %%
import random
import string
import time

start_time = time.time()

target = "PEMROGRAMAN LANJUTAN"
population_size = 100
mutation_rate = 0.04
generations = 10000
elite_size = 20
top_parents_size = 20  # Jumlah individu teratas yang aka n dipertimbangkan sebagai orang tua

def initialize_population(size, length):
    return [''.join(random.choices(string.ascii_uppercase + " ", k=length)) for _ in range(size)]

def calculate_fitness(individual):
    return sum(1 for i, j in zip(individual, target) if i == j)

def selection(population, top_size):
    # Mengambil individu dengan fitness tertinggi
    top_individuals = population[:top_size]
    # Memilih dua orang tua secara acak dari individu dengan fitness tertinggi
    return random.sample(top_individuals, 2)

def crossover(parent1, parent2):
    length = len(parent1)
    
    crossover_points = sorted(random.sample(range(1, length), 4))
    
    child1 = (parent1[:crossover_points[0]] + parent2[crossover_points[0]:crossover_points[1]] +
              parent1[crossover_points[1]:crossover_points[2]] + parent2[crossover_points[2]:crossover_points[3]] +
              parent1[crossover_points[3]:])
    
    child2 = (parent2[:crossover_points[0]] + parent1[crossover_points[0]:crossover_points[1]] +
              parent2[crossover_points[1]:crossover_points[2]] + parent1[crossover_points[2]:crossover_points[3]] +
              parent2[crossover_points[3]:])
    
    child3 = (parent1[:crossover_points[1]] + parent2[crossover_points[1]:crossover_points[2]] +
              parent1[crossover_points[2]:crossover_points[3]] + parent2[crossover_points[3]:])
    
    child4 = (parent2[:crossover_points[1]] + parent1[crossover_points[1]:crossover_points[2]] +
              parent2[crossover_points[2]:crossover_points[3]] + parent1[crossover_points[3]:])
    
    child5 = (parent1[:crossover_points[2]] + parent2[crossover_points[2]:crossover_points[3]] +
              parent1[crossover_points[3]:])
    
    return child1, child2, child3, child4, child5

def mutate(individual, mutation_rate):
    return ''.join(
        char if random.random() > mutation_rate else random.choice(string.ascii_uppercase + " ")
        for char in individual
    )

def genetic_algorithm():
    population = initialize_population(population_size, len(target))
    for generation in range(generations):
        population = sorted(population, key=calculate_fitness, reverse=True)
        best_individual = population[0]
        best_fitness = calculate_fitness(best_individual)
        
        print(f"Generation {generation + 1}: Best fitness = {best_fitness}, Best individual = {best_individual}")
        
        if best_fitness == len(target):
            break
        
        next_population = population[:elite_size]  # Elitism: keep top individuals
        
        while len(next_population) < population_size:
            parent1, parent2 = selection(population, top_parents_size)  # Seleksi orang tua dari individu teratas
            child1, child2, child3, child4, child5 = crossover(parent1, parent2)
            next_population.extend([mutate(child1, mutation_rate), mutate(child2, mutation_rate), 
                                    mutate(child3, mutation_rate), mutate(child4, mutation_rate), 
                                    mutate(child5, mutation_rate)])
        
        population = next_population[:population_size]
    
    return best_individual

# Running the genetic algorithm
best_individual = genetic_algorithm()
print(f"Best individual: {best_individual}")
print(f'\nWaktu komputasi: {time.time()- start_time}')
waktu = time.time() - start_time
print('Kecepatan Running: ', round((generations+1)/waktu), 'generasi/detik\n')
# Out:
# Generation 1: Best fitness = 4, Best individual = RYASSGQAWTYYFDZAUTUS
# Generation 2: Best fitness = 5, Best individual = OVPX GQAWTYXVWNAUTUJ
# Generation 3: Best fitness = 6, Best individual = ZEASSGQAWONMOGTNUEON
# Generation 4: Best fitness = 7, Best individual = PMQSOMQAMIGXXWNAUTWS
# Generation 5: Best fitness = 9, Best individual = ZEASODVAMONMLHNAUEON
# Generation 6: Best fitness = 10, Best individual = ZYASODVAMONMLANAUTON
# Generation 7: Best fitness = 11, Best individual = ZEASOPVAMONMLANLUTEN
# Generation 8: Best fitness = 12, Best individual = PEQSODVAMONTLANAUTON
# Generation 9: Best fitness = 12, Best individual = PEQSODVAMONTLANAUTON
# Generation 10: Best fitness = 13, Best individual = PEASOGIAMON AANAUTON
# Generation 11: Best fitness = 14, Best individual = PEQROMQAMTN LANLUTON
# Generation 12: Best fitness = 14, Best individual = PEQROMQAMTN LANLUTON
# Generation 13: Best fitness = 16, Best individual = PEQROGQAMTN LANJUTUN
# Generation 14: Best fitness = 16, Best individual = PEQROGQAMTN LANJUTUN
# Generation 15: Best fitness = 16, Best individual = PEQROGQAMTN LANJUTUN
# Generation 16: Best fitness = 17, Best individual = PEQROGQAMAN LANOUTAN
# Generation 17: Best fitness = 17, Best individual = PEQROGQAMAN LANOUTAN
# Generation 18: Best fitness = 18, Best individual = PEQROGVAMAN LANJUTAN
# Generation 19: Best fitness = 18, Best individual = PEQROGVAMAN LANJUTAN
# Generation 20: Best fitness = 18, Best individual = PEQROGVAMAN LANJUTAN
# Generation 21: Best fitness = 18, Best individual = PEQROGVAMAN LANJUTAN
# Generation 22: Best fitness = 18, Best individual = PEQROGVAMAN LANJUTAN
# Generation 23: Best fitness = 18, Best individual = PEQROGVAMAN LANJUTAN
# Generation 24: Best fitness = 18, Best individual = PEQROGVAMAN LANJUTAN
# Generation 25: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 26: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 27: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 28: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 29: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 30: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 31: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 32: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 33: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 34: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 35: Best fitness = 19, Best individual = PEQROGRAMAN LANJUTAN
# Generation 36: Best fitness = 20, Best individual = PEMROGRAMAN LANJUTAN
# Best individual: PEMROGRAMAN LANJUTAN
#
# Waktu komputasi: 0.06400299072265625
# Kecepatan Running:  156258 generasi/detik
