# %%
import pandas as pd
import numpy as np

# %%
# Menggunakan List
student_data = [
    [100, 90,10],
    [90,70, 7],
    [120, 100, 14],
    [80, 50, 2]
]
df = pd.DataFrame(student_data, columns=['iq','marks','packaged'])
df #pengganti print
# Out:
#     iq  marks  packaged
# 0  100     90        10
# 1   90     70         7
# 2  120    100        14
# 3   80     50         2

# %%
# Mengubah Nama Kolom lagi
df.columns = ['a', 'b', 'c']
df #pengganti print
# Out:
#      a    b   c
# 0  100   90  10
# 1   90   70   7
# 2  120  100  14
# 3   80   50   2

# %%
# Menggunkan Dictionary
student_dict = {
    'iq': [100, 90, 80, 120, 0, 0],
    'marks': [80,70,100,90,0,0],
    'packaged': [10,7,14,2,0,0]
}
students = pd.DataFrame(student_dict)
students
# Out:
#     iq  marks  packaged
# 0  100     80        10
# 1   90     70         7
# 2   80    100        14
# 3  120     90         2
# 4    0      0         0
# 5    0      0         0

# %%
# Memanggil Dictionary tertentu
students [['iq']]
# Out:
#     iq
# 0  100
# 1   90
# 2   80
# 3  120
# 4    0
# 5    0

# %%
#Mengimpor file
data = pd.read_csv('ms_harga_harian.csv')
data_produk = pd.read_csv('ms_produk.csv')

data
# Out:
#         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0      PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1      PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2      PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3      PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4      PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# ...             ...                  ...         ...                   ...
# 45013  PROD-0000037  2008-12-31 00:00:00  CABANG-065                  5280
# 45014  PROD-0000038  2008-12-31 00:00:00  CABANG-065                  6270
# 45015  PROD-0000039  2008-12-31 00:00:00  CABANG-065                  5640
# 45016  PROD-0000040  2008-12-31 00:00:00  CABANG-065                 15380
# 45017  PROD-0000041  2008-12-31 00:00:00  CABANG-065                 14450
#
#        modal_cabang  biaya_cabang
# ...

# %%
data_produk
# Out:
#      kode_produk kode_kategori                       nama_produk  unit  \
# 0   PROD-0000001       KTG-003                  bawang merah 1kg     1
# 1   PROD-0000002       KTG-003                 bawang putih 1 kg     1
# 2   PROD-0000003       KTG-003                       buncis 1 kg     1
# 3   PROD-0000004       KTG-003               kacang panjang 1 kg     1
# 4   PROD-0000005       KTG-003                 kacang hijau 1 kg     1
# 5   PROD-0000006       KTG-003                      kentang 1 kg     1
# 6   PROD-0000007       KTG-003                      ketimun 1 kg     1
# 7   PROD-0000008       KTG-003                        kobis 1 kg     1
# 8   PROD-0000009       KTG-003                        tomat 1 kg     1
# 9   PROD-0000010       KTG-003               ubi kayu basah 1 kg     1
# 10  PROD-0000011       KTG-003                    ubi jalar 1 kg     1
# 11  PROD-0000012       KTG-003                       wortel 1 kg     1
# ...

# %%
print (data.shape)
print (data.columns)
# Out:
# (45018, 6)
# Index(['kode_produk', 'tgl_berlaku', 'kode_cabang', 'harga_berlaku_cabang',
#        'modal_cabang', 'biaya_cabang'],
#       dtype='object')

# %%
#menagmbil data teratas
data.head(6) #6 = jumlah data teratas yang ingin ditampilkan
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# 5  PROD-0000006  2008-01-01 00:00:00  CABANG-039                  8110
#
#    modal_cabang  biaya_cabang
# 0         10380           190
# 1          4040            10
# 2          5900            90
# 3          7620            60
# 4          6860            10
# 5          7770            10

# %%
#mengambil data akhir
data.tail()
# Out:
#         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 45013  PROD-0000037  2008-12-31 00:00:00  CABANG-065                  5280
# 45014  PROD-0000038  2008-12-31 00:00:00  CABANG-065                  6270
# 45015  PROD-0000039  2008-12-31 00:00:00  CABANG-065                  5640
# 45016  PROD-0000040  2008-12-31 00:00:00  CABANG-065                 15380
# 45017  PROD-0000041  2008-12-31 00:00:00  CABANG-065                 14450
#
#        modal_cabang  biaya_cabang
# 45013          5060            70
# 45014          5960            90
# 45015          5350           130
# 45016         14570            80
# 45017         13600            90

# %%
df5000 = data[(data['modal_cabang'] < 5000)]

# %%
#Data tunggal pada "Kode Cabang"
print(df5000['kode_cabang'].unique())

#panjang data
print(len(df5000['kode_produk'].unique()))
# Out:
# ['CABANG-039' 'CABANG-047' 'CABANG-065']
# 13

# %%
len(data[(data['kode_produk'] == "PROD-0000001")])
# Out:
# 1098

# %%
data.head()
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
#
#    modal_cabang  biaya_cabang
# 0         10380           190
# 1          4040            10
# 2          5900            90
# 3          7620            60
# 4          6860            10

# %%
data['data_tambahan'] = data['modal_cabang'] + 5000
data.head()
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
#
#    modal_cabang  biaya_cabang  data_tambahan
# 0         10380           190          15380
# 1          4040            10           9040
# 2          5900            90          10900
# 3          7620            60          12620
# 4          6860            10          11860

# %% [markdown]
# TUGAS
# 1. Dalam dataframe `data` tambahkan kolom `nama produk` yang berasal dari data_produk
# 2. Buat Data Frame `jumlah produk` yang menunjukkan jumlah produk 1 sampai 41 beserta total harganya

# %%
# Tugas 1
data['nama produk'] = data_produk["nama_produk"]
data.head()
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
#
#    modal_cabang  biaya_cabang  data_tambahan          nama produk
# 0         10380           190          15380     bawang merah 1kg
# 1          4040            10           9040    bawang putih 1 kg
# 2          5900            90          10900          buncis 1 kg
# 3          7620            60          12620  kacang panjang 1 kg
# 4          6860            10          11860    kacang hijau 1 kg

# %%
#Tugas 2
#Total Harga Semua Produk
result_list = []

for i in range(1, 41):
    kode_produk = f"PROD-00000{i:02d}"
    total_harga = sum(data[(data['kode_produk'] == kode_produk)]['harga_berlaku_cabang'])
    result_list.append({'kode_produk': kode_produk, 'total_harga': total_harga})

result_df = pd.DataFrame(result_list)

# Jumlah Produk
result_list = []

for i in range(1, 42):  # Perulangan hingga 41 kali
    kode_produk = f"PROD-00000{i:02d}"
    jumlah_produk = len(data[(data['kode_produk'] == kode_produk)])
    result_list.append({'kode_produk': kode_produk, 'jumlah_produk': count_produk})
result_jumlah_produk = pd.DataFrame(result_list)

data['total'] = result_df['total_harga']
data['jumlah_produk'] = result_jumlah_produk["jumlah_produk"]
data.head()
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
#
#    modal_cabang  biaya_cabang  data_tambahan          nama produk       total  \
# 0         10380           190          15380     bawang merah 1kg  12723420.0
# 1          4040            10           9040    bawang putih 1 kg   4700600.0
# 2          5900            90          10900          buncis 1 kg   6966440.0
# 3          7620            60          12620  kacang panjang 1 kg   9085770.0
# 4          6860            10          11860    kacang hijau 1 kg   7905370.0
#
#    jumlah_produk
# 0         1098.0
# 1         1098.0
# ...
